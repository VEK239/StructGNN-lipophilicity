# %%
from rdkit import Chem

# %%
mol = Chem.MolFromSmiles("Nc1ccc(O)c2ncccc12")
display(mol)

# %%
mol = Chem.MolFromSmiles("C1=CC%11=C9C2=C1C=C3C(=C2)C=C4C(=C3)C=CC5=C4C6=C(C=C5)C=CC7=C6C=C8C(=C7)C=C%10C(=C8)C9=C(C=C%10)C=C%11")
display(mol)

# %%
mol = Chem.MolFromSmiles("C1CC3C2C(CCC1)C=CC(=C2C3)CC(C)C")
display(mol)

# %%
mol = Chem.MolFromSmiles("C1CCC3C(CC1)CC(C2C(CCCC2)N[S](C(C)C4=CC=CC3=C4)(=C)=O)C5CCCCC5")
display(mol)

# %%
mol = Chem.MolFromSmiles("C1=CC=NC(=C1)NS(=O)(=O)C2=CC=C(C=C2)NN=C3C=CC(=O)C(=C3)C(=O)O")
display(mol)
